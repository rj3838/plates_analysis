# %%
# !pip install Pyarrow
import pandas as pd

# %%
#df = pd.read_csv(r'\\trllimited\data\Vehicle_Validation_SCANNER\Accreditation\2023\WDM\RAV16\Plates\LONG-PM-NS-R1_R16_230302151337_S1_TEX.dat')
df = pd.read_csv(r'\\trllimited\data\INF_TRACS\TRACS5\1 - Accreditation\RAV17\5-Accreditation-May23\CC Output\TRACS4\Plates\Texture\RAV17_NS_Run_1_A.dat')

# %%
minimum_texture = min(df.Texture)

adjustment_value = abs(minimum_texture)

#df.adjusted_Tex = df.Texture + adjustment_value
df['adjusted_Tex'] = df.apply(lambda row: row.Texture + adjustment_value, axis=1)

readings_per_metre = len(df.Chainage) / max(df.Chainage)
print("readings per metre", readings_per_metre)
hertz = readings_per_metre/2
print("hertz", hertz)
# Out:
# readings per metre 1004.9065493028047
# hertz 502.45327465140235

# %%
from matplotlib import pyplot as plt


print(len(df.Chainage))
plt.subplots(figsize=(20,5))
plt.plot(df.Chainage, df.Texture)
# Out:
# 16724

# %%
# %pip install noisereduce
# Out:
# Requirement already satisfied: noisereduce in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (3.0.0)
# Requirement already satisfied: scipy in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from noisereduce) (1.12.0)
# Requirement already satisfied: matplotlib in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from noisereduce) (3.8.2)
# Requirement already satisfied: librosa in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from noisereduce) (0.10.1)
# Requirement already satisfied: numpy in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from noisereduce) (1.26.3)
# Requirement already satisfied: tqdm in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from noisereduce) (4.66.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (1.4.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from librosa->noisereduce) (1.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: colorama in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from tqdm->noisereduce) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from numba>=0.51.0->librosa->noisereduce) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from scikit-learn>=0.20.0->librosa->noisereduce) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from soundfile>=0.12.1->librosa->noisereduce) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->noisereduce) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
#TODO

#filter out the 500Hz noise. The hertz is hertz from above...
# is has been suggested by MC to reduce the filter frequency.
# seems to be best at 490 moving the filter to 500 removes the signal.

# Import the required packages
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, savgol_filter
import noisereduce as nr

# Generate a noisy signal
# np.random.seed(0)
# fs = 1000 # sampling frequency
# t = np.linspace(0, 1, fs) # time vector
# f = 5 # signal frequency
# x = np.sin(2 * np.pi * f * t) # clean signal
# noise = 0.5 * np.random.randn(fs) # white noise
# y = x + noise # noisy signal

# t should be time, in this case it's distance
t = df.Chainage
# f=frequency which is the number of readings per metre /2 it assumes a sine wave !
f=500 # (near enough)
# y is the actual data (Texture)
y=df.Texture
# fs is sample frequency, so length of Texture (number of readings)/ max of the sample chainage(length of data in metres)
fs=(len(df.Texture)/ max(df.Chainage))

# Plot the noisy signal
# plt.figure(figsize=(12, 4))
# plt.plot(t, y, label='Noisy signal')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')
# plt.legend()
# plt.show()

# Apply a low-pass filter
fc = 490 # cut-off frequency
w = fc / (fs / 0.25) # normalized frequency
b, a = butter(4, w, 'low') # 4th order low-pass Butterworth filter
y_lp = filtfilt(b, a, y) # apply the filter to the signal

# Plot the filtered signal
plt.figure(figsize=(20, 4))
#plt.plot(t, y, label='Noisy signal',linewidth=1)
plt.plot(t, y_lp, label='Low-pass filtered signal',linewidth=0.25)
plt.xlabel('Distance (metres)')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 11
#       9 import matplotlib.pyplot as plt
#      10 from scipy.signal import butter, filtfilt, savgol_filter
# ---> 11 import noisereduce as nr
#      13 # Generate a noisy signal
#      14 # np.random.seed(0)
#      15 # fs = 1000 # sampling frequency
#    (...)
#      21
#      22 # t should be time, in this case it's distance
#      23 t = df.Chainage
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\noisereduce\__init__.py:1
# ----> 1 from noisereduce.noisereduce import reduce_noise
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\noisereduce\noisereduce.py:1
# ----> 1 from noisereduce.spectralgate.stationary import SpectralGateStationary
#       2 from noisereduce.spectralgate.nonstationary import SpectralGateNonStationary
#       4 try:
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\noisereduce\spectralgate\__init__.py:3
#       1 from .nonstationary import SpectralGateNonStationary
#       2 from .stationary import SpectralGateStationary
# ----> 3 from .streamed_torch_gate import StreamedTorchGate
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\noisereduce\spectralgate\streamed_torch_gate.py:1
# ----> 1 import torch
#       2 from noisereduce.spectralgate.base import SpectralGate
#       3 from noisereduce.torchgate import TorchGate as TG
#
# ModuleNotFoundError: No module named 'torch'

# %%
from scipy import fftpack
import numpy as np
signal_noise = df.Texture
sec = readings_per_metre/2
time = np.linspace(0, len(df.Texture), len(df.Texture), endpoint=True).astype(int)

sig_noise_fft = fftpack.fft(signal_noise.values)
sig_noise_amp = 2 / time.size * np.abs(sig_noise_fft)
sig_noise_freq = np.abs(fftpack.fftfreq(time.size, readings_per_metre))

# %%
print(sig_noise_amp)
print(sig_noise_freq)
# Out:
# [16.20736666  2.11146794  1.68664728 ...  1.66664194  1.68664728
#   2.11146794]
# [0.00000000e+00 5.95023563e-08 1.19004713e-07 ... 1.78507069e-07
#  1.19004713e-07 5.95023563e-08]

# %%
plt.plot(sig_noise_freq, sig_noise_amp)

# %%
signal_amplitude = pd.Series(sig_noise_amp).nlargest(2).round(0).astype(int).tolist()
print(signal_amplitude)
# Out:
# [16, 3]

# %%
#Calculate Frequency Magnitude
magnitudes = abs(sig_noise_fft[np.where(sig_noise_freq >= 0)])
#Get index of top 2 frequencies
peak_frequency = np.sort((np.argpartition(magnitudes, -2)[-2:])/sec)
print(peak_frequency)
# Out:
# [0.         0.00796094]

# %%
from scipy.signal import butter,filtfilt
# Filter requirements.
#fs = 1000.0       # sample rate, Hz
fs=400
cutoff = peak_frequency[1]     # desired cutoff frequency of the filter, Hz ,      slightly higher than actual 2 Hz
order = 2       # sin wave can be approx represented as quadratic
def butter_lowpass_filter(data, cutoff, fs, order):
    print("Cutoff freq " + str(cutoff))
    nyq = 0.5 * fs # Nyquist Frequency
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a,data)
    return y
# Filter the data, and plot filtered signals.
y = butter_lowpass_filter(signal_noise, cutoff, fs, order)
# Out:
# Cutoff freq 0.007960939259028941

# %%
plt.plot(df.Chainage, y)

# %%
import numpy as np
from scipy import signal
data = {}
data['before'] = df.Texture
data['after_fir'] = signal.lfilter(np.ones(len(data)), 1, data['before'])
data['after_iir'] = signal.lfilter([1], [1,-0.5], data['before'])

# %%
plt.subplots(figsize=(20,5))
plt.plot(df.Chainage, data['before'], label='before',lw=1)
#plt.plot(df.Chainage, data['after_fir'], label='FIR',lw=1)
plt.plot(df.Chainage, data['after_iir'], label='IIR',lw=1)
#plt.subplots(figsize=(10,5))

# %%
import numpy as np
import scipy.signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
from scipy.signal import sosfiltfilt, butter

def bandpass(data: np.ndarray, edges: list[float], sample_rate: float, poles: int = 5):
    sos = scipy.signal.butter(poles, edges, 'bandpass', fs=sample_rate, output='sos')
    filtered_data = scipy.signal.sosfiltfilt(sos, data)
    return filtered_data

# Load sample data from a WAV file
#sample_rate, data = scipy.io.wavfile.read(df.Texture)
#times = np.arange(len(data))/sample_rate

#sosfiltfilt(sos.)
x = df.adjusted_Tex
sos = butter(6, 0.125, btype='highpass', analog=True, output='sos')
y = sosfiltfilt(sos, x)
t=df.Chainage

from scipy.signal import sosfilt, sosfilt_zi
#sos8 = butter(8, 0.125, output='sos')
#zi = x[:4].mean() * sosfilt_zi(sos8)
#y2, zo = sosfilt(sos8, x, zi=zi)
plt.subplots(figsize=(20,5))
plt.plot(t, x, alpha=0.5, label='x(t)')
plt.plot(t, y, label='y(t)')
#plt.plot(t, y2, label='y2(t)')
plt.legend(framealpha=1, shadow=True)
plt.grid(alpha=0.25)
plt.xlabel('t')
#plt.subplots(figsize=(20,5))
plt.show()

# %%
# %pip install nbformat
# Out:
# Collecting nbformat
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastjsonschema (from nbformat)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: jupyter-core in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from nbformat) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from nbformat) (5.14.1)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.33.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.17.1-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from jupyter-core->nbformat) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rjaques\appdata\local\continuum\anaconda3\envs\p3_12_1\lib\site-packages (from jupyter-core->nbformat) (305.1)
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/77.6 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 77.6/77.6 kB 1.1 MB/s eta 0:00:00
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB 4.7 MB/s eta 0:00:00
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.33.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.17.1-cp312-none-win_amd64.whl (205 kB)
#    ---------------------------------------- 0.0/205.7 kB ? eta -:--:--
#    ----------------------------- ---------- 153.6/205.7 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 205.7/205.7 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 nbformat-5.9.2 referencing-0.33.0 rpds-py-0.17.1

# %%
import numpy as np
from scipy.signal import butter,sosfiltfilt
import plotly.graph_objects as go

#sample_rate = (len(df)/2)/max(df.Chainage)

sample_period = max(df.Chainage)
sample_rate = 8000
n = len(df) # total number of samples
nyq = 0.5 * sample_rate
cutoff=1
order=8 # started at 2
data = df.adjusted_Tex

def butter_filter(data, cutoff, fs, order):
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    sos = butter(order, normal_cutoff, btype='highpass', analog=True, output='sos')
    y = sosfiltfilt(sos, data)
    return y

# Filter the data, and plot both the original and filtered signals.
filtered_y = butter_filter(data, cutoff, sample_rate, order)
fig = go.Figure()
# fig.add_trace(go.Scatter(
#             y = data,
#             line =  dict(shape =  'spline' ),
#             name = 'signal with noise'
#             ))
fig.add_trace(go.Scatter(
            y = filtered_y,
            line =  dict(shape =  'linear',
                         width=0.5 ),
            name = 'filtered signal'
            ))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 36
#      25 # fig.add_trace(go.Scatter(
#      26 #             y = data,
#      27 #             line =  dict(shape =  'spline' ),
#      28 #             name = 'signal with noise'
#      29 #             ))
#      30 fig.add_trace(go.Scatter(
#      31             y = filtered_y,
#      32             line =  dict(shape =  'linear',
#      33                          width=0.5 ),
#      34             name = 'filtered signal'
#      35             ))
# ---> 36 fig.show()
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# now get the high frequency noise out...
# problem is that this data is not based on time but the x-axis is distance (mm)

from scipy.fft import rfft,rfftfreq,fftfreq
import numpy as np
import matplotlib.pyplot as plt

freqs = fftfreq(len(filtered_y), 8000)
t= np.arange(0,8000, 1)
from scipy.fft import rfft,rfftfreq
data_step   = 0.004
f_noise = filtered_y
n    = len(filtered_y)
yf   = rfft(f_noise)
xf   = rfftfreq(n,data_step)
#plt.plot(xf,np.abs(yf))

yf_abs      = np.abs(yf) 
indices     = yf_abs>1   # filter out those value under 300
yf_clean    = indices * yf # noise frequency will be set to 0
plt.plot(xf,np.abs(yf_clean))
#t           = np.arange(start=0,stop=1,step=data_step)

# n    = len(t)
# yf   = rfft(f_noise)
# xf   = rfftfreq(n,data_step)
# plt.plot(xf,np.abs(yf))


# yf_abs      = np.abs(filtered_y) 
# indices     = yf_abs>2   # filter out those value under 300
# yf_clean    = indices * filtered_y # noise frequency will be set to 0
# plt.plot(df.Chainage,np.abs(yf_clean))

# %%
n = len(df.Texture)
dt = 1
fhat = np.fft.fft(df.Texture, n)
psd = fhat * np.conj(fhat)/n
freq = (1/n) * np.arange(n) #frequency array
idxs_half = np.arange(1, np.floor(n), dtype=np.int32) #first half index

# %%
threshold = 10
signal = df.Texture[:8000]
signal_clean = signal
psd_idxs = psd > threshold #array of 0 and 1
psd_clean = psd * psd_idxs #zero out all the unnecessary powers
fhat_clean = psd_idxs * fhat #used to retrieve the signal
minsignal, maxsignal = signal.min(), signal.max()
signal_filtered = np.fft.ifft(fhat_clean) #inverse fourier transform
signal_filtered = signal_filtered[:8000]

# %%
## Visualization

fig, ax = plt.subplots(4,1)
ax[0].plot(t, signal, color='b', lw=0.5, label='Noisy Signal')
ax[0].plot(t, signal_clean, color='r', lw=1, label='Clean Signal')
ax[0].set_ylim([minsignal, maxsignal])
ax[0].set_xlabel('t axis')
ax[0].set_ylabel('Vals')
ax[0].legend()

ax[1].plot(freq[idxs_half], np.abs(psd[idxs_half]), color='b', lw=0.5, label='PSD noisy')
ax[1].set_xlabel('Frequencies in Hz')
ax[1].set_ylabel('Amplitude')
ax[1].legend()

ax[2].plot(freq[idxs_half], np.abs(psd_clean[idxs_half]), color='r', lw=1, label='PSD clean')
ax[2].set_xlabel('Frequencies in Hz')
ax[2].set_ylabel('Amplitude')
ax[2].legend()

ax[3].plot(t, signal_filtered, color='r', lw=0.5, label='Clean Signal Retrieved')
ax[3].set_ylim([minsignal, maxsignal])
ax[3].set_xlabel('t axis')
ax[3].set_ylabel('Vals')
ax[3].legend()

plt.subplots_adjust(hspace=0.4)
# Out:
# c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning:
#
# Casting complex values to real discards the imaginary part
#
# c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning:
#
# Casting complex values to real discards the imaginary part

# %%
plt.subplots(figsize=(20,5))
plt.plot(t, signal_filtered, color='r', lw=0.5, label='Clean Signal Retrieved')
#plt.set_ylim([minsignal, maxsignal])
#plt.set_xlabel('t axis')
#plt.set_ylabel('Vals')

# %%
from scipy.fft import irfft
new_f_clean = irfft(yf_abs)
plt.plot(t,new_f_clean[:8000])
plt.ylim(-6,8)
# Out:
# (-6.0, 8.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 0, 500

#x = np.arange(1, len(df), 0.1)  # x axis
#z = np.random.normal(mu, sigma, len(x))  # noise
# y from previous cell
#y = x ** 2 + z  # data
plt.subplots(figsize=(20,5))
plt.plot(t, y, linewidth=0.25)  # it includes some noise

from scipy.signal import lfilter

n = 30  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b, a, y)
#plt.plot(x, yy, linewidth=2, linestyle="-", c="b")  # smooth by filter

# from scipy.signal import savgol_filter
# w = savgol_filter(y, 50, 2)
# plt.plot( w, x, 'b')  # high frequency noise removed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 11
#       6 #x = np.arange(1, len(df), 0.1)  # x axis
#       7 #z = np.random.normal(mu, sigma, len(x))  # noise
#       8 # y from previous cell
#       9 #y = x ** 2 + z  # data
#      10 plt.subplots(figsize=(20,5))
# ---> 11 plt.plot(t, y, linewidth=0.25)  # it includes some noise
#      13 from scipy.signal import lfilter
#      15 n = 30  # the larger n is, the smoother curve will be
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\rjaques\AppData\Local\Continuum\anaconda3\envs\p3_12_1\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (8000,) and (16724,)

# %%
# the frequency of the noise is the length of the signal/2
# noise_frequency = (len(df)/2)/ max(df.Chainage)

# sos = signal.butter(4, Wn=(noise_frequency/4), btype='highpass', fs=(noise_frequency*2), output='sos')
# filtered = signal.sosfilt(sos, sig)
# ax2.plot(t, filtered)
# ax2.set_title('After 15 Hz high-pass filter')
# ax2.axis([0, 1, -2, 2])
# ax2.set_xlabel('Time [seconds]')
# plt.tight_layout()
# plt.show()

# %%
# max(df.Chainage)/len(df.Chainage) * 2

# %%
# n = len(df.Chainage)
# fhat = np.fft.fft(y, n) #computes the fft
# psd = fhat * np.conj(fhat)/n
# #freq = (1/(dt*n)) * np.arange(n) #frequency array
# hertz = max(df.Chainage)/len(df.Chainage) * 2
# idxs_half = np.arange(1, np.floor(n/2), dtype=np.int32) #first half index

# %%
# remove the noise from the filtered signal
# the filtered signal is y from cell above

from scipy.fft import rfft,rfftfreq
n    = len(t)
yf   = rfft(y)
x =df.Chainage[::2]

y=np.abs(yf)
y = np.delete(y, -1)
#xf   = rfftfreq(n,data_step)
plt.plot(x,y)

# %%
from scipy.fft import fft, fftfreq

# Number of samples in normalized_tone
SAMPLE_RATE = max(df.Chainage)/len(df.Chainage)
print(SAMPLE_RATE)
DURATION = max(df.Chainage)
print(DURATION)
N = int(len(df))
temp_fft = scipy.fftpack.fft(np.array(y))
yf = scipy.fftpack.fft(temp_fft, axis=-1)
#yf = fft(normalized_tone)
xf = fftfreq(N, 1/SAMPLE_RATE)

plt.plot(np.abs(yf))
plt.show()
# Out:
# 0.0009951174073786176
# 16.642343521

# %%
#points_per_freq = len(xf)/(SAMPLE_RATE/2)
#target_idx = int(points_per_freq * 4000)
xf = df.iloc[1::2]
xf= xf.Chainage
yf[1 : 4] = 0
plt.plot(xf, np.abs(yf))
plt.show()

# %%
from scipy.fft import irfft

new_sig = irfft(yf)
df_sub = df.head(-2)
plt.subplots(figsize=(20,5))
plt.plot(df_sub.Chainage, new_sig)
plt.show()

# %%
import scipy.signal

d1 = df.Texture
N = len(d1)
#d1_fft = fft(df.adjusted_Tex)
x_axis = d1[1:N]
#f = LinRange(-0.5, 0.5, N+1)[1:N]  # normalized frequency 
fs = 1;   # sampling frequency
fc = 0.005;  # frequency cutoff, less than Fnyquist=0.5
filt = digitalfilter(Highpass(fc,fs=fs), Butterworth(6));
d2 = filtfilt(filt, d1)  #filtered signal
p1 = plot(x_axis[1:N], d2[1:N], lw=1,label="Filtered flipped signal",xlabel="Time", legend=topleft)
#plot!(t[1:N÷2], d3_trunc[1:N÷2], ls=:dash,lc=:black, lw=1,label="From truncated spectrum (100 points)")
plot(p1, size=(4000,1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 10
#       8 fs = 1;   # sampling frequency
#       9 fc = 0.005;  # frequency cutoff, less than Fnyquist=0.5
# ---> 10 filt = digitalfilter(Highpass(fc,fs=fs), Butterworth(6));
#      11 d2 = filtfilt(filt, d1)  #filtered signal
#      12 p1 = plot(x_axis[1:N], d2[1:N], lw=1,label="Filtered flipped signal",xlabel="Time", legend=topleft)
#
# NameError: name 'digitalfilter' is not defined

# %%
import numpy as np
import scipy.signal
import scipy.io.wavfile
import matplotlib.pyplot as plt

def bandpass(data: np.ndarray, edges: list[float], sample_rate: float, poles: int = 5):
    sos = scipy.signal.butter(poles, edges, 'bandpass', fs=sample_rate, output='sos')
    filtered_data = scipy.signal.sosfiltfilt(sos, data)
    return filtered_data

# Load sample data from a WAV file
sample_rate, data = scipy.io.wavfile.read(df.Texture)
times = np.arange(len(data))/sample_rate

# Apply a 10-50 Hz high-pass filter to the original data
filtered = bandpass(data, [10, 50], sample_rate)
